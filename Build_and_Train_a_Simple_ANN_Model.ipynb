# %% [markdown]
# <a href="https://colab.research.google.com/github/NileeshaDM/IT21269516/blob/main/Build_and_Train_a_Simple_ANN_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Data

# %%
import pandas as pd

df = pd.read_csv('Mobile_Price_Classification.csv', encoding='latin-1')
df.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
X = df.drop(['price_range'],axis=1)
y = df['price_range']
print(y)
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1995    0
# 1996    0
# 1997    1
# 1998    0
# 1999    1
# Name: price_range, Length: 2000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
pip list

# %% [markdown]
# # Import Dependencies

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout

# %% [markdown]
# # Build Model

# %%
model = Sequential()
model.add(Dense(units = 8, activation = 'relu', input_dim=len(X_train.columns))) #relu assign -values to 0
model.add(Dense(units = 4, activation = 'relu'))
model.add(Dense(units=1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 8)                 168
#
#  dense_1 (Dense)             (None, 4)                 36
#
#  dense_2 (Dense)             (None, 1)                 5
#
# ...
# Total params: 209
# Trainable params: 209
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd',metrics='accuracy')

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 8ms/step - loss: 63.0853 - accuracy: 0.5100 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 2/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.5067 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 3/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.5067 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 4/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6931 - accuracy: 0.5067 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 5/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6931 - accuracy: 0.5067 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 6/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.5067 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 7/100
# ...

# %%
model.save('weights.h5')
